# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemBaron/baron_vergeles/blob/main/ml_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
list = range(1,10,1)
for i in list:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
nums = [1,2,3,4,5]
new = []
[i * 2 for i in nums]
[True if i > 2 else False for i in nums]
# Out:
# [False, False, True, True, True]

# %%
nums = [1,2,3,4,5]

# %%
def mult2(nums, i = 2):
  new = []
  for num in nums:
    new.append(num * i)
  return new

# %%
nums1 = [45,24,13,14,545]

# %%
mult2(nums1, 5)
# Out:
# [225, 120, 65, 70, 2725]

# %%
d = {'a': 1,
        'b': 23,
        'c': 44,
        'd': 74,
        'e': 12,
        }

# %%
d['a']
d.get('b', 'notfound')
d.setdefault('g', 86)
# Out:
# 86

# %%
professions = ['IT', 'Физика', 'Математика']
persons = [['Гейтс', 'Джобс', 'Возняк'], ['Эйнштейн', 'Фейнман'], ['Эвклид', 'Ньютон']]
zip(professions)
persons.pop()
persons
# Out:
# [['Гейтс', 'Джобс', 'Возняк'], ['Эйнштейн', 'Фейнман']]

# %%
while len(nums) > 2:
  nums.pop()

# %%
it_specialists = [('Jhn', 'DE', 150), ('Krl', 'DA', 120), ('Gl', 'DS',300)]

# %%
class ItSpecialists:
  def __init__(self, name, speciality, salary):
    self.name = name
    self.speciality = speciality
    self.salary = salary
  
  def tell_about_yourself(self):
    return f'Hi, my name is {self.name}.I\'m a {self.speciality}, my salary is {self.salary}'

# %%
jon = ItSpecialists('Jhn', 'DE', 150)

# %%
jon.name
# Out:
# 'Jhn'

# %%
crl = ItSpecialists('Krl', 'DA', 120)

# %%
#method
crl.tell_about_yourself()
# Out:
# "Hi, my name is Krl.I'm a DA, my salary is 120"

# %%
#наследование
class DataScientists(ItSpecialists):
  def ml(self, data):
    return 'profit'

# %%
gl = DataScientists('Gl', 'DS',300)

# %%
gl.ml([1,4,5,6,-13])
# Out:
# 'profit'

# %%
#наследование
class DataScientists(ItSpecialists):
  
  def __init__(self, name, salary):
    super().__init__(name, 'DS', salary)

  def ml(self, data):
    return 'profit'

# %%
gl = DataScientists('Gl',300)

# %%
gl.tell_about_yourself()
# Out:
# "Hi, my name is Gl.I'm a DS, my salary is 300"

# %%
gl.ml([1,4,5,6,-13])
# Out:
# 'profit'

# %%
#наследование
class DataScientists(ItSpecialists):
  
  def __init__(self, name, salary):
    super().__init__(name, 'DS', salary)

  def tell_about_yourself(self):
    return f'Hi, my name is {self.name}.I\'m a {self.speciality}, my salary is {self.salary} k per sec'

  def ml(self, data):
    return 'profit'

# %%
gl.tell_about_yourself()
# Out:
# "Hi, my name is Gl.I'm a DS, my salary is 300 k per sec"

# %% [markdown]
# Pandas part

# %%
df = pd.read_csv('/content/drive/MyDrive/content/aug_train.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.drop('city', axis = 1)
#inplace = False
# Out:
#        enrollee_id  city_development_index gender      relevent_experience  \
# 0             8949                   0.920   Male  Has relevent experience
# 1            29725                   0.776   Male   No relevent experience
# 2            11561                   0.624    NaN   No relevent experience
# 3            33241                   0.789    NaN   No relevent experience
# 4              666                   0.767   Male  Has relevent experience
# ...            ...                     ...    ...                      ...
# 19153         7386                   0.878   Male   No relevent experience
# 19154        31398                   0.920   Male  Has relevent experience
# 19155        24576                   0.920   Male  Has relevent experience
# 19156         5756                   0.802   Male  Has relevent experience
# 19157        23834                   0.855    NaN   No relevent experience
#
# ...

# %%
df.assign(new_col3 = 99)
#не трогает исходный дф без сохранения
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
city_40 = df[(df['city'] == 'city_40') & (df['gender'] == 'Male')].copy()

# %%
df.loc[df['city'] == 'city_40', :]
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.isna().mean().sort_values(ascending=False)
#доли пропусков
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# relevent_experience       0.000000
# training_hours            0.000000
# target                    0.000000
# dtype: float64

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
q = df['city_development_index'].quantile(0.25)

# %%
df[df['city_development_index'] < q]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 2            11561   city_21                   0.624    NaN
# 10           29452   city_21                   0.624    NaN
# 13            5826   city_21                   0.624   Male
# 14            8722   city_21                   0.624    NaN
# 17            5764   city_21                   0.624    NaN
# ...            ...       ...                     ...    ...
# 19144        17191   city_21                   0.624    NaN
# 19145          155   city_44                   0.725    NaN
# 19147        21319   city_21                   0.624   Male
# 19148         9212   city_21                   0.624    NaN
# 19151        11385  city_149                   0.689   Male
#
#            relevent_experience enrolled_university education_level  \
# 2       No relevent experience    Full time course        Graduate
# 10      No relevent experience    Full time course     High School
# ...

# %%
df['target'].mean()
# Out:
# 0.24934753105752167

# %%
t = df.groupby('gender', dropna = False)['target'].agg(['count', 'mean'])

# %%
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
df.groupby('education_level', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'], 5)

# %%
df.groupby('city_development_index_group', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index_group_q'] = pd.qcut(df['city_development_index'], 5,  duplicates = 'drop')
#equal number based on quantiles

# %%
df.groupby('city_development_index_group_q', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                                 count      mean
# city_development_index_group_q
# (0.447, 0.691]                   3869  0.550530
# (0.691, 0.878]                   3827  0.206428
# (0.878, 0.92]                    8925  0.178375
# (0.92, 0.949]                    2537  0.104454

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'], [0, 0.1, 0.2, 0.5, float('inf')])

# %%
df.groupby('city_development_index_group_custom', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                                      count      mean
# city_development_index_group_custom
# (0.0, 0.1]                               0       NaN
# (0.1, 0.2]                               0       NaN
# (0.2, 0.5]                              63  0.587302
# (0.5, inf]                           19095  0.248233

# %%
def education_group(x):
  if x in set(['High School', 'Primary School']): #быстрее
    return 'school'
  elif x in ['Masters', 'Phd']:
    return 'Masters_Phd'
  else:
    return x

# %%
df['new_education_level'] = df['education_level'].apply(education_group)

# %%
df.groupby('new_education_level', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_Phd           4775  0.207958
# school                2325  0.187097
# NaN                    460  0.226087

# %%
df['education_level'].replace('Primary School', 'School')

# %%
d = {'Primary School': 'School'}

# %%
df['education_level'].map(d)

# %%
def new_training_hours(row):
  if row['education_level'] == 'Phd':
    return row['training_hours'] + 1000
  else:
    return row['training_hours']

# %%
df['new_training_hours'] = df.apply(new_training_hours, axis = 1)

# %%
df[df['education_level'] == 'Phd']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 37           10164  city_114                   0.926   Male
# 121          13915   city_16                   0.910   Male
# 130           3921   city_36                   0.893    NaN
# 135          23947  city_103                   0.920    NaN
# 152          31786  city_103                   0.920   Male
# ...            ...       ...                     ...    ...
# 18738         1477  city_162                   0.767   Male
# 18800        18365  city_103                   0.920   Male
# 18807          229  city_114                   0.926   Male
# 18944         2678  city_104                   0.924    NaN
# 19044        14441   city_89                   0.925   Male
#
#            relevent_experience enrolled_university education_level  \
# 37     Has relevent experience       no_enrollment             Phd
# 121    Has relevent experience       no_enrollment             Phd
# ...

# %%
df.groupby('new_education_level', dropna = False)['target'].agg(['count', 'mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_Phd           4775  0.207958
# school                2325  0.187097
# NaN                    460  0.226087

# %%
df['new_education_level'] = df['new_education_level'].fillna('no_info')
df['gender'] = df['gender'].fillna('no_info')

# %%
t = df.pivot_table(index = 'new_education_level', values = 'target', aggfunc = ['mean', 'count'], margins = True)

# %%
t.reset_index()
# Out:
#   new_education_level      mean  count
#                          target target
# 0            Graduate  0.279790  11598
# 1         Masters_Phd  0.207958   4775
# 2             no_info  0.226087    460
# 3              school  0.187097   2325
# 4                 All  0.249348  19158

# %%
t.columns = ['_'.join(i).strip() for i in t.columns.values]

# %%
t = t.reset_index()

# %%
t
# Out:
#   new_education_level  mean_target  count_target
# 0            Graduate     0.279790         11598
# 1         Masters_Phd     0.207958          4775
# 2             no_info     0.226087           460
# 3              school     0.187097          2325
# 4                 All     0.249348         19158

# %%
df.pivot_table(index = 'new_education_level', values = 'target', columns = ['gender', 'enrolled_university'], aggfunc = ['mean', 'count'], margins = True)
# Out:
#                                 mean                                 \
# gender                        Female
# enrolled_university Full time course Part time course no_enrollment
# new_education_level
# Graduate                    0.441860         0.224490      0.242735
# Masters_Phd                 0.409091         0.222222      0.201835
# no_info                     0.000000         0.000000      0.250000
# school                      0.390244         0.333333      0.047619
# All                         0.421296         0.230769      0.224120
#
#                                                                      \
# gender                          Male
# enrolled_university Full time course Part time course no_enrollment
# new_education_level
# Graduate                    0.410409         0.220561      0.225279
# Masters_Phd                 0.382979         0.208955      0.158967
# no_info                     0.275862         0.272727      0.155280
# ...

# %%
t = df.pivot_table(index = 'new_education_level', values = 'target', columns = 'gender', aggfunc = 'mean')

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='gender', ylabel='new_education_level'>

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target', 'new_education_level'],
#       dtype='object')

# %%
df[['city_development_index','training_hours','target']].corr()
# Out:
#                         city_development_index  training_hours    target
# city_development_index                1.000000        0.001920 -0.341665
# training_hours                        0.001920        1.000000 -0.021577
# target                               -0.341665       -0.021577  1.000000

# %%
! pip install phik
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['enrollee_id', 'city_development_index', 'training_hours', 'target']

# %%
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
phik_overview['target'].sort_values(ascending=False)
#Phik в отличии от Пирсона показывает нелинейные связи
# Out:
# target                    1.000000
# city_development_index    0.482287
# city                      0.477283
# experience                0.238725
# relevent_experience       0.199859
# new_education_level       0.132478
# gender                    0.116653
# last_new_job              0.114708
# enrolled_university       0.093803
# education_level           0.075999
# company_size              0.071953
# enrollee_id               0.067472
# company_type              0.066792
# major_discipline          0.029200
# training_hours            0.026849
# Name: target, dtype: float64

# %%
t = df.groupby('city', dropna = False)['target'].agg(['count', 'mean'])

# %%
t.sort_values('count', ascending = False).head(10)['mean'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %%
t = df.groupby('city')[['target','city_development_index']].agg(['count','mean'])

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t.sort_values('target_count',ascending=False).head(10)
# Out:
#           target_count  target_mean  city_development_index_count  \
# city
# city_103          4355     0.213088                          4355
# city_21           2702     0.591044                          2702
# city_16           1533     0.116765                          1533
# city_114          1336     0.099551                          1336
# city_160           845     0.235503                           845
# city_136           586     0.104096                           586
# city_67            431     0.132251                           431
# city_75            305     0.101639                           305
# city_102           304     0.171053                           304
# city_104           301     0.093023                           301
#
#           city_development_index_mean
# city
# city_103                        0.920
# city_21                         0.624
# city_16                         0.910
# city_114                        0.926
# ...

# %%
df['experience_int'] = df['experience'].replace('<1','0').replace('>20','999').fillna(-1).astype(int)

# %%
df['experience_group'] = pd.qcut(df['experience_int'],5)

# %%
df.groupby('experience_group')['target'].agg(['count','mean'])
# Out:
#                   count      mean
# experience_group
# (-1.001, 4.0]      5020  0.358964
# (4.0, 6.0]         2646  0.285336
# (6.0, 11.0]        4459  0.239740
# (11.0, 18.0]       3295  0.170561
# (18.0, 999.0]      3738  0.157571

# %%
df.groupby('experience_group')['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='experience_group'>

# %%
t = pd.DataFrame({'col1':[1,2,3,float('nan')],
                  'col2':['a','b','c','d'],
                  'col3':[0]*3 + [1]*1,
                  'col4':[0,0,0,1]})

# %%
t
# Out:
#    col1 col2  col3  col4
# 0   1.0    a     0     0
# 1   2.0    b     0     0
# 2   3.0    c     0     0
# 3   NaN    d     1     1

# %%
t = pd.DataFrame({'col1':[1,2,3,float('nan')]})

# %%
t['col1'].sum()
# Out:
# 6.0

# %%
t['col1'].mean()
# Out:
# 2.0

# %%
t['col1'].count()
# Out:
# 3

# %%
len(t)
# Out:
# 4

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts()
# Out:
# Male       13221
# no_info     4508
# Female      1238
# Other        191
# Name: gender, dtype: int64

# %%
df['gender'] = df['gender'].replace('no_info',float('nan'))

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
t = pd.DataFrame({'x':[1,2,3],'y':[1,3,2]})

# %%
t.plot(x='x',y='y',kind='scatter', grid = True)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df[df['experience_int'] < 999].plot(x='city_development_index',y='experience_int',kind='scatter',alpha=0.01)
#alpha -  прозрачность

# %%
(df[df['experience_int'] < 999]
 .groupby('city_development_index_group_q')
 ['experience_int'].agg(['count','mean','median']))
# Out:
#                                 count      mean  median
# city_development_index_group_q
# (0.447, 0.691]                   3768  5.603238     5.0
# (0.691, 0.878]                   3408  7.936620     7.0
# (0.878, 0.92]                    6733  8.576860     8.0
# (0.92, 0.949]                    1963  9.099338     9.0

# %%
(df[df['experience_int'] < 999]
 .groupby('city_development_index_group_q')
 ['experience_int'].mean()).plot(ylim=0)
# Out:
# <Axes: xlabel='city_development_index_group_q'>

# %%
age = df[['enrollee_id']].copy()

# %%
age['age'] = 30
age.head(1)
# Out:
#    enrollee_id  age
# 0         8949   30

# %%
df = df.merge(age, how = 'left', on = 'enrollee_id')

# %%
len(age)
# Out:
# 19158

# %%
len(age['enrollee_id'].drop_duplicates())
# Out:
# 19158

# %%
#join по индексу
#df.join()
#df.set_index('enrollee_id')

# %%
type(df['city_development_index'].values)
# Out:
# numpy.ndarray

# %%
np.mean([1,2,3,4,5])
# Out:
# 3.0

# %%
np.random.normal()
# Out:
# 0.14321868325943263

# %%
list(range(-10,10,0.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-38c4b0bafaa1> in <cell line: 1>()
# ----> 1 list(range(-10,10,0.5))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
np.linspace(-10, 10, 20)
# Out:
# array([-10.        ,  -8.94736842,  -7.89473684,  -6.84210526,
#         -5.78947368,  -4.73684211,  -3.68421053,  -2.63157895,
#         -1.57894737,  -0.52631579,   0.52631579,   1.57894737,
#          2.63157895,   3.68421053,   4.73684211,   5.78947368,
#          6.84210526,   7.89473684,   8.94736842,  10.        ])

# %%
np.random.uniform(size=10) / 100
# Out:
# array([0.00873873, 0.00053228, 0.00351494, 0.00723462, 0.0069667 ,
#        0.00302341, 0.00771475, 0.00833208, 0.00879943, 0.00389839])

# %% [markdown]
# https://drive.google.com/drive/folders/1se8FAU8p6oY85jngUzzPGSG5IyQr1w2K?usp=sharing

# %%
! gdown --id 1se8FAU8p6oY85jngUzzPGSG5IyQr1w2K
! unzip -o /content/uk-used-cars.zip -d /content/uk-used-cars
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1se8FAU8p6oY85jngUzzPGSG5IyQr1w2K

# %%
df = pd.read_csv('/content/drive/MyDrive/uk-used-cars/bmw.csv')

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.25, random_state=42)

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 930    5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 4052   1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 1197         X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 7893   2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 7571   1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 5734   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 5191   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 5390         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 860          X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 7270   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize
# 930          2.0
# 4052         1.5
# 1197         3.0
# 7893         2.0
# 7571         1.5
# ...

# %%
train.isna().mean()
# Out:
# model           0.0
# year            0.0
# price           0.0
# transmission    0.0
# mileage         0.0
# fuelType        0.0
# tax             0.0
# mpg             0.0
# engineSize      0.0
# dtype: float64

# %%
train['price'].hist()
# Out:
# <Axes: >

# %%
train['price'].describe()
# Out:
# count      8085.000000
# mean      22668.821645
# std       11469.825387
# min        1445.000000
# 25%       14800.000000
# 50%       20022.000000
# 75%       27850.000000
# max      123456.000000
# Name: price, dtype: float64

# %%
train.groupby('year')['price'].agg(['count','mean','median'])
# Out:
#       count          mean   median
# year
# 1996      1   5995.000000   5995.0
# 1997      1   3950.000000   3950.0
# 1998      1   3950.000000   3950.0
# 1999      3   3980.000000   3995.0
# 2000      1   1550.000000   1550.0
# 2001      3   7333.333333   5950.0
# 2002      4   3893.500000   3494.5
# 2003      2   9222.500000   9222.5
# 2004      7   7932.857143   3495.0
# 2005      6   5390.166667   4685.0
# 2006     12   5445.250000   3942.5
# 2007     12   5027.833333   4597.5
# 2008     18   6004.666667   5272.5
# 2009     22   6506.090909   5845.0
# 2010     31   7374.129032   6495.0
# 2011     37   8860.297297   8470.0
# 2012     92   9432.923913   8990.0
# 2013    253  11041.347826  10490.0
# 2014    384  13411.333333  12797.5
# 2015    716  15086.536313  14103.5
# 2016   1398  16531.655222  15699.5
# 2017   1296  19205.839506  18299.5
# 2018    635  22562.450394  21000.0
# 2019   2598  31066.986143  27980.0
# 2020    552  35359.445652  32450.5

# %%
train.groupby('year')['price'].median().plot()
# Out:
# <Axes: xlabel='year'>

# %%
train['price_pred_mean'] = train['price'].mean()

# %%
train['err'] = train['price_pred_mean'] - train['price']

# %%
train['err_abs'] = abs(train['err'])

# %%
train['err_abs'].mean()
# Out:
# 8450.556631461715

# %%
train['err_abs_pct'] = train['err_abs'] / train['price']

# %%
train['err_abs_pct'].mean()
# Out:
# 0.48316912602731443

# %%
train['price_pred_median'] = train['price'].median()

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
mean_absolute_error(train['price'],train['price_pred_median'])
# Out:
# 8450.556631461715

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_median'])
# Out:
# 0.41711111879393314

# %%
test['price_pred_median'] = train['price'].median()

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 8728   1 Series  2018  15300       Manual    36469   Diesel  150   50.4
# 761    5 Series  2014  15495    Semi-Auto    51565   Diesel  160   51.4
# 7209         X3  2019  39875    Semi-Auto     8988   Diesel  150   36.7
# 6685   2 Series  2019  21730    Automatic     5054   Petrol  145   39.2
# 8548   2 Series  2018  13799       Manual    13369   Diesel  145   65.7
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 9825   4 Series  2019  25500    Automatic     3250   Petrol  145   48.7
# 3522   7 Series  2019  52700    Semi-Auto      706   Diesel  145   44.1
# 9757   3 Series  2017  15795    Automatic    64000   Hybrid    0  134.5
# 6100   4 Series  2019  29840    Automatic     6000   Diesel  145   60.1
# 3946   4 Series  2020  34980    Semi-Auto     1000   Petrol  145   48.7
#
#       engineSize  price_pred_median
# 8728         1.5            20022.0
# ...

# %%
mean_absolute_percentage_error(test['price'],test['price_pred_median'])
# Out:
# 0.409212791738344

# %%
train.groupby('year')['price'].agg(['count','mean','median'])
# Out:
#       count          mean   median
# year
# 1996      1   5995.000000   5995.0
# 1997      1   3950.000000   3950.0
# 1998      1   3950.000000   3950.0
# 1999      3   3980.000000   3995.0
# 2000      1   1550.000000   1550.0
# 2001      3   7333.333333   5950.0
# 2002      4   3893.500000   3494.5
# 2003      2   9222.500000   9222.5
# 2004      7   7932.857143   3495.0
# 2005      6   5390.166667   4685.0
# 2006     12   5445.250000   3942.5
# 2007     12   5027.833333   4597.5
# 2008     18   6004.666667   5272.5
# 2009     22   6506.090909   5845.0
# 2010     31   7374.129032   6495.0
# 2011     37   8860.297297   8470.0
# 2012     92   9432.923913   8990.0
# 2013    253  11041.347826  10490.0
# 2014    384  13411.333333  12797.5
# 2015    716  15086.536313  14103.5
# 2016   1398  16531.655222  15699.5
# 2017   1296  19205.839506  18299.5
# 2018    635  22562.450394  21000.0
# 2019   2598  31066.986143  27980.0
# 2020    552  35359.445652  32450.5

# %%
model_year_mean = train.groupby('year')['price'].mean().reset_index()

# %%
model_year_mean.columns = ['year', 'price_pred_year_mean']

# %%
train = train.merge(model_year_mean, how = 'left', on = 'year')

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize  price_pred_year_mean
# 0            2.0          11041.347826
# ...

# %%
 mean_absolute_error(train['price'],train['price_pred_year_mean'])
# Out:
# 5474.243598515644

# %%
 mean_absolute_percentage_error(train['price'],train['price_pred_year_mean'])
# Out:
# 0.2447228468704618

# %%
test = test.merge(model_year_mean, how = 'left', on = 'year')

# %%
test.isna().mean()
# Out:
# model                   0.0
# year                    0.0
# price                   0.0
# transmission            0.0
# mileage                 0.0
# fuelType                0.0
# tax                     0.0
# mpg                     0.0
# engineSize              0.0
# price_pred_year_mean    0.0
# dtype: float64

# %%
 mean_absolute_error(test['price'],test['price_pred_year_mean'])
# Out:
# 5426.271071211102

# %%
 mean_absolute_percentage_error(test['price'],test['price_pred_year_mean'])
# Out:
# 0.23933940428873632

# %%
model_year_median = train.groupby('year')['price'].median().reset_index()

# %%
model_year_median = model_year_median.rename({'price':'price_pred_year_median'},axis=1)

# %%
train = train.merge(model_year_median, how = 'left', on = 'year')

# %%
 mean_absolute_error(train['price'],train['price_pred_year_median'])
# Out:
# 5232.327891156463

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_year_median'])
# Out:
# 0.21723436816638503

# %%
test = test.merge(model_year_median,how='left',on='year')

# %%
mean_absolute_error(test['price'],test['price_pred_year_median'])
# Out:
# 5240.677299703264

# %%
mean_absolute_percentage_error(test['price'],test['price_pred_year_median'])
# Out:
# 0.21478293590399475

# %%
train.groupby('engineSize')[['price','year']].agg(['count','mean','median'])
# Out:
#            price                         year
#            count          mean   median count         mean  median
# engineSize
# 0.0           32  18469.906250  18250.0    32  2015.843750  2017.0
# 0.6            6  17973.333333  18200.0     6  2016.333333  2016.5
# 1.0            1  17400.000000  17400.0     1  2015.000000  2015.0
# 1.5         1146  17104.345550  15881.5  1146  2017.582024  2017.0
# 1.6           75   9230.240000   8890.0    75  2013.626667  2014.0
# 1.9            5   3968.000000   3950.0     5  1998.400000  1999.0
# 2.0         4925  20697.721624  19792.0  4925  2017.068629  2017.0
# 2.2            4   6010.000000   3972.5     4  2003.250000  2003.0
# 2.5            8   4532.375000   3892.5     8  2005.250000  2005.5
# 2.8            1   5995.000000   5995.0     1  1996.000000  1996.0
# 3.0         1818  31545.723872  27058.0  1818  2017.116062  2017.0
# 3.2            3  16116.333333  17850.0     3  2004.333333  2004.0
# ...

# %%
def engine_group(x):
  if x <= 1.5:
    return "<=1.5"
  elif x <= 2:
    return "<=2"
  else:
    return ">2"

# %%
train['engine_group'] = train['engineSize'].apply(engine_group)

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize  price_pred_year_median engine_group
# 0            2.0                 10490.0          <=2
# ...

# %%
t = train.groupby('engine_group')['price'].agg(['count','mean','median'])

# %%
t['count'].sum()
# Out:
# 8085

# %%
len(train)
# Out:
# 8085

# %%
t
# Out:
#               count          mean   median
# engine_group
# <=1.5          1185  17145.870886  15980.0
# <=2            5005  20509.168232  19499.0
# >2             1895  31826.479683  27500.0

# %%
train['engine_group2'] = pd.cut(train['engineSize'],[-float('inf'),1.5,2,float('inf')])

# %%
train.groupby('engine_group2')['price'].agg(['count','mean','median'])
# Out:
#                count          mean   median
# engine_group2
# (-inf, 1.5]     1185  17145.870886  15980.0
# (1.5, 2.0]      5005  20509.168232  19499.0
# (2.0, inf]      1895  31826.479683  27500.0

# %%
model_year_engine_median = train.groupby(['year','engine_group'])['price'].median().reset_index()

# %%
model_year_engine_median.head()
# Out:
#    year engine_group   price
# 0  1996           >2  5995.0
# 1  1997          <=2  3950.0
# 2  1998          <=2  3950.0
# 3  1999          <=2  3995.0
# 4  2000           >2  1550.0

# %%
t = train.pivot_table(index = 'year', columns = 'engine_group', values = 'price', aggfunc= 'median')

# %%
t
# Out:
# engine_group    <=1.5      <=2       >2
# year
# 1996              NaN      NaN   5995.0
# 1997              NaN   3950.0      NaN
# 1998              NaN   3950.0      NaN
# 1999              NaN   3995.0      NaN
# 2000              NaN      NaN   1550.0
# 2001          13000.0      NaN   4500.0
# 2002              NaN   3999.0   2990.0
# 2003              NaN      NaN   9222.5
# 2004              NaN   1970.0   8750.0
# 2005              NaN   4375.0   4995.0
# 2006              NaN   2992.5   5344.5
# 2007              NaN   3495.0   5994.0
# 2008              NaN   3992.5   7642.5
# 2009              NaN   4740.0   9490.0
# 2010              NaN   5995.0   9125.0
# 2011              NaN   7624.0  10500.0
# 2012              NaN   8500.0  12970.0
# 2013              NaN   9990.0  15895.5
# 2014          14972.5  11945.0  16656.0
# 2015          10999.0  13490.0  18144.5
# 2016          11809.0  15500.0  19996.5
# 2017          14292.5  17625.0  22980.5
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='engine_group', ylabel='year'>

# %%
model_year_engine_median = model_year_engine_median.rename({'price':'price_pred_year_engine_median'},axis=1)

# %%
train = train.merge(model_year_engine_median,how='left',on=['year','engine_group'])

# %%
mean_absolute_error(train['price'],train['price_pred_year_median'])
# Out:
# 5232.327891156463

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_year_median'])
# Out:
# 0.21723436816638503

# %%
mean_absolute_error(train['price'],train['price_pred_year_engine_median'])
# Out:
# 3659.774273345702

# %%
mean_absolute_percentage_error(train['price'],train['price_pred_year_engine_median'])
# Out:
# 0.1582922021242831

# %%
test['engine_group'] = test['engineSize'].apply(engine_group)

# %%
test = test.merge(model_year_engine_median,how='left',on=['year','engine_group'])

# %%
test.isna().mean()
# Out:
# model                            0.000000
# year                             0.000000
# price                            0.000000
# transmission                     0.000000
# mileage                          0.000000
# fuelType                         0.000000
# tax                              0.000000
# mpg                              0.000000
# engineSize                       0.000000
# price_pred_year_median           0.000000
# engine_group                     0.000000
# price_pred_year_engine_median    0.000742
# dtype: float64

# %%
test[test['price_pred_year_engine_median'].isna()]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 415    3 Series  1999   1200    Automatic    82000   Petrol  245  31.0
# 2255   5 Series  2000   1699       Manual    99209   Petrol  265  29.4
#
#       engineSize  price_pred_year_median engine_group  \
# 415          2.8                  3995.0           >2
# 2255         2.0                  1550.0          <=2
#
#       price_pred_year_engine_median
# 415                             NaN
# 2255                            NaN

# %%
def error(y_true, y_pred):
  print(mean_absolute_error(y_true,y_pred))
  print(mean_absolute_percentage_error(y_true,y_pred))

# %%
error(train['price'],train['price_pred_year_median'])
error(test['price'],test['price_pred_year_median'])
error(train['price'],train['price_pred_year_engine_median'])

test_no_nan = test.dropna().copy()


error(test_no_nan['price'],test_no_nan['price_pred_year_engine_median'])
# Out:
# 5232.327891156463
# 0.21723436816638503
# 5240.677299703264
# 0.21478293590399475
# 3659.774273345702
# 0.1582922021242831
# 3790.014291017075
# 0.16270961023342095

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      5 Series  2013  12791    Semi-Auto    55642   Diesel  145  55.4
# 1      1 Series  2019  23995    Semi-Auto     1527   Petrol  145  43.5
# 2            X5  2015  25995    Automatic    43344   Diesel  200  47.1
# 3      2 Series  2019  25000    Automatic     4000   Petrol  145  47.9
# 4      1 Series  2015  10950       Manual    33000   Diesel   20  72.4
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   3 Series  2018  17995    Semi-Auto    40456   Diesel  145  64.2
# 8081   1 Series  2016  19950    Semi-Auto    23210   Petrol  200  39.8
# 8082         X2  2019  25450    Semi-Auto     5652   Diesel  145  47.9
# 8083         X1  2016  19850    Semi-Auto    14542   Diesel  125  60.1
# 8084   1 Series  2016  15745    Automatic    17237   Petrol  125  54.3
#
#       engineSize  price_pred_year_median engine_group engine_group2  \
# ...

# %%
train.groupby('transmission')['price'].agg(['count','mean','median'])
# Out:
#               count          mean   median
# transmission
# Automatic      2698  22413.452187  19392.0
# Manual         1925  14557.851429  13450.0
# Semi-Auto      3462  27377.835066  24990.0

# %%
model_year_engine_median
# Out:
#     year engine_group  price_pred_year_engine_median
# 0   1996           >2                         5995.0
# 1   1997          <=2                         3950.0
# 2   1998          <=2                         3950.0
# 3   1999          <=2                         3995.0
# 4   2000           >2                         1550.0
# 5   2001        <=1.5                        13000.0
# 6   2001           >2                         4500.0
# 7   2002          <=2                         3999.0
# 8   2002           >2                         2990.0
# 9   2003           >2                         9222.5
# 10  2004          <=2                         1970.0
# 11  2004           >2                         8750.0
# 12  2005          <=2                         4375.0
# 13  2005           >2                         4995.0
# 14  2006          <=2                         2992.5
# 15  2006           >2                         5344.5
# 16  2007          <=2                         3495.0
# ...

# %%
train.groupby('year')['price'].agg(['count','median'])
# Out:
#       count   median
# year
# 1996      1   5995.0
# 1997      1   3950.0
# 1998      1   3950.0
# 1999      3   3995.0
# 2000      1   1550.0
# 2001      3   5950.0
# 2002      4   3494.5
# 2003      2   9222.5
# 2004      7   3495.0
# 2005      6   4685.0
# 2006     12   3942.5
# 2007     12   4597.5
# 2008     18   5272.5
# 2009     22   5845.0
# 2010     31   6495.0
# 2011     37   8470.0
# 2012     92   8990.0
# 2013    253  10490.0
# 2014    384  12797.5
# 2015    716  14103.5
# 2016   1398  15699.5
# 2017   1296  18299.5
# 2018    635  21000.0
# 2019   2598  27980.0
# 2020    552  32450.5

# %%
train['year_group'] = pd.cut(train['year'],[0,2010,2012,2014,2016,2018,float('inf')])

# %%
train.groupby('year_group')['price'].agg(['count','median'])
# Out:
#                   count   median
# year_group
# (0.0, 2010.0]       124   5584.0
# (2010.0, 2012.0]    129   8985.0
# (2012.0, 2014.0]    637  11695.0
# (2014.0, 2016.0]   2114  15080.5
# (2016.0, 2018.0]   1931  19370.0
# (2018.0, inf]      3150  28867.5

# %%
model_year_engine_group_median = train.groupby(['year_group','engine_group'])['price'].median().reset_index()

# %%
model_year_engine_group_median
# Out:
#           year_group engine_group    price
# 0      (0.0, 2010.0]        <=1.5  13000.0
# 1      (0.0, 2010.0]          <=2   4097.0
# 2      (0.0, 2010.0]           >2   6990.0
# 3   (2010.0, 2012.0]        <=1.5      NaN
# 4   (2010.0, 2012.0]          <=2   8470.0
# 5   (2010.0, 2012.0]           >2  12245.0
# 6   (2012.0, 2014.0]        <=1.5  14972.5
# 7   (2012.0, 2014.0]          <=2  10998.0
# 8   (2012.0, 2014.0]           >2  16345.0
# 9   (2014.0, 2016.0]        <=1.5  11557.0
# 10  (2014.0, 2016.0]          <=2  14800.0
# 11  (2014.0, 2016.0]           >2  19497.5
# 12  (2016.0, 2018.0]        <=1.5  14999.0
# 13  (2016.0, 2018.0]          <=2  18980.0
# 14  (2016.0, 2018.0]           >2  24480.0
# 15     (2018.0, inf]        <=1.5  21500.0
# 16     (2018.0, inf]          <=2  27990.0
# 17     (2018.0, inf]           >2  46000.0

# %%
model_year_engine_group_median = model_year_engine_group_median.rename({'price':'pred_price_year_engine_group_median'},axis=1)

# %%
train = train.merge(model_year_engine_group_median,how='left',on=['year_group','engine_group'])

# %%
error(train['price'],train['price_pred_year_engine_median'])
# Out:
# 3659.774273345702
# 0.1582922021242831

# %%
error(train['price'],train['pred_price_year_engine_group_median'])
# Out:
# 3827.4336425479282
# 0.1693848259731495

# %%
model_year_engine_trn_group_median = (train.groupby(['year_group',
                                                     'engine_group',
                                                     'transmission'])
                                            ['price'].median().reset_index())

# %%
model_year_engine_trn_group_median
# Out:
#           year_group engine_group transmission    price
# 0      (0.0, 2010.0]        <=1.5    Automatic      NaN
# 1      (0.0, 2010.0]        <=1.5       Manual  13000.0
# 2      (0.0, 2010.0]        <=1.5    Semi-Auto      NaN
# 3      (0.0, 2010.0]          <=2    Automatic   5982.5
# 4      (0.0, 2010.0]          <=2       Manual   3995.0
# 5      (0.0, 2010.0]          <=2    Semi-Auto   5695.0
# 6      (0.0, 2010.0]           >2    Automatic   5997.0
# 7      (0.0, 2010.0]           >2       Manual   8800.0
# 8      (0.0, 2010.0]           >2    Semi-Auto  10995.0
# 9   (2010.0, 2012.0]        <=1.5    Automatic      NaN
# 10  (2010.0, 2012.0]        <=1.5       Manual      NaN
# 11  (2010.0, 2012.0]        <=1.5    Semi-Auto      NaN
# 12  (2010.0, 2012.0]          <=2    Automatic   9440.0
# 13  (2010.0, 2012.0]          <=2       Manual   7490.0
# 14  (2010.0, 2012.0]          <=2    Semi-Auto      NaN
# 15  (2010.0, 2012.0]           >2    Automatic  12245.0
# ...

# %%
pd.options.display.max_rows = 99

# %%
model_year_engine_trn_group_median = model_year_engine_trn_group_median.rename({'price':'price_pred_year_engine_trn_median'},axis=1)

# %%
train = train.merge(model_year_engine_trn_group_median,how='left',
            on=['year_group','engine_group','transmission'])

# %%
error(train['price'],train['price_pred_year_engine_trn_median'])
# Out:
# 3635.5412492269634
# 0.1561691679065392

# %%
test['year_group'] = pd.cut(test['year'],[0,2010,2012,2014,2016,2018,float('inf')])

# %%
test = test.merge(model_year_engine_trn_group_median,how='left',
            on=['year_group','engine_group','transmission'])

# %%
test.isna().mean()
# Out:
# model                                0.000000
# year                                 0.000000
# price                                0.000000
# transmission                         0.000000
# mileage                              0.000000
# fuelType                             0.000000
# tax                                  0.000000
# mpg                                  0.000000
# engineSize                           0.000000
# price_pred_year_median               0.000000
# engine_group                         0.000000
# price_pred_year_engine_median        0.000742
# year_group                           0.000000
# price_pred_year_engine_trn_median    0.001113
# dtype: float64

# %%
test_no_na = test.dropna().copy()

# %%
error(test_no_na['price'],test_no_na['price_pred_year_engine_trn_median'])
# Out:
# 3777.5172798216277
# 0.16037327734163415

# %%
b

# %%
v
